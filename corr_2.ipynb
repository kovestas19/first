# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
water = pd.read_csv('C:\\Users\\koves\\Desktop\\Magistratura\\Python\\water.csv')
water.head()
# Out:
#    Unnamed: 0 location        town  mortality  hardness
# 0           1    South        Bath       1247       105
# 1           2    North  Birkenhead       1668        17
# 2           3    South  Birmingham       1466         5
# 3           4    North   Blackburn       1800        14
# 4           5    North   Blackpool       1609        18

# %%
#Повторение всех пунктов из Задание1, но в разрезе округов, т.е. отдельно для North и South

# %%
north = water[water['location']=='North']
south = water[water['location']=='South']

# %%
#1.Построить точечный график
north.plot(kind = 'scatter', x='hardness',y='mortality')

south.plot(kind = 'scatter', x='hardness',y='mortality')
# Out:
# <Axes: xlabel='hardness', ylabel='mortality'>

# %%
#2.Рассчитать коэффиценты корреляции Пирсона и Спирмена
south[['hardness','mortality']].corr()
# Out:
#            hardness  mortality
# hardness   1.000000  -0.602153
# mortality -0.602153   1.000000

# %%
south[['hardness','mortality']].corr(method='spearman')
# Out:
#            hardness  mortality
# hardness   1.000000  -0.595723
# mortality -0.595723   1.000000

# %%
north[['hardness','mortality']].corr()
# Out:
#            hardness  mortality
# hardness   1.000000  -0.368598
# mortality -0.368598   1.000000

# %%
north[['hardness','mortality']].corr(method='spearman')
# Out:
#            hardness  mortality
# hardness   1.000000  -0.404208
# mortality -0.404208   1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#3-4.Построить модель линейной регрессии и рассчитать коэффицент детерминации 
def linearRegress(data):
    x = data[['hardness']]
    y = data[['mortality']]
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)
    model = LinearRegression()
    model.fit(x_train,y_train)
    return model.score(x_test,y_test)

linearRegress(north)
linearRegress(south)
# Out:
# 0.5501913104689536
